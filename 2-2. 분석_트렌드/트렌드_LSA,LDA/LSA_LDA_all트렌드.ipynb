# %% [markdown]
# # <b> 1. LSA(Latent Semantic Analysis)</b>

# %%
import nltk
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from nltk.tokenize import TreebankWordTokenizer
# Out:
# C:\Users\cutad\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df14 = pd.read_csv('../트렌드_전처리데이터/14트렌드_전처리.csv')
df23 = pd.read_csv('../트렌드_전처리데이터/23트렌드_전처리.csv')
df24 = pd.read_csv('../트렌드_전처리데이터/24트렌드_전처리.csv')
df = pd.concat([df14, df23, df24], ignore_index=True)
df.head()
# Out:
#    postdate                                               body  \
# 0  20231128  안녕하세요 패션스타일리스트 여러분 오늘은 새로운 도전의 시간입니다 함께 2014년의...
# 1  20231220  안녕하세요 패션 열정을 품고 있는 여러분 오늘은 2014년의 트렌드를 다시 한 번 ...
# 2  20231215  안녕하세요 패션 열정을 키우는 여러분 오늘은 패션의 과거에서 영감을 받아 새로운 스...
# 3  20231222  안녕하세요 패션스타일리스트 여러분 오늘은 2014년의 패션 트렌드를 다시 한 번 살...
# 4  20240216  안녕하세요 패션 열정을 품고 있는 여러분 오늘은 2014년에 빛난 패션 트렌드를 살...
#
#                                          description  \
# 0  이제 여러분은 b2014년b의 b트렌드b를 기반으로 하여 자유롭고 창의적인 패션 여...
# 1  이를 바탕으로 자신만의 스타일을 찾고 2014년의 패션 트렌드를 따라할 수 있습니다...
# 2  b2014년b 특히 눈에 띄었던 b트렌드b 중 하나는 플라워 패턴의 활용이었습니다 ...
# 3  플로럴 패턴 꽃 무늬를 활용한 플로럴 패턴은 b2014년b의 b트렌드b 중 하나였습...
# 4  b2014년b 패션 b트렌드b의 다양한 스타일을 살펴보았습니다 여러분은 어떤 스타일...
#
#                                  title  \
# 0          패션 스타일링의 예술 2014년 트렌드를 바탕으로
# 1  2014년 패션 트렌드를 익히고 자신만의 스타일로 빛나게 하세요
# 2   패션의 시간을 거슬러 2014년 트렌드로 떠나는 스타일링 여행
# 3            2014년 트렌드를 반영한 다양한 패션 스타일
# 4     2014년 패션 트렌드 패션스타일리스트의 추천 TOP 10
#
#                                    preprocessed_body  \
# 0  패션 스타일리스트 은 도전 패션 독창 패션 스타일링 은 관행 독특 스타일 환영 해 ...
# 1  패션 열정 은 번 스타일 알리 은 패션 스타일 인기 해 은 중 인기 패션 스타일 빈...
# 2  패션 열정 은 패션 과거 영감 스타일 스타일리스트 팁 현대 룩 연출 것 눈 중 플라...
# 3  패션 스타일리스트 은 패션 번 스타일 은 패션 스타일 해 중 패션 스타일 스타일링 ...
# 4  패션 열정 은 빛 패션 패션 스타일리스트 대표 옷 스타일 패션 스타일 중 글 스타일...
#
#                             preprocessed_description preprocessed_title
# 0                           은 자유 적 패션 라 독특 개성 스타일 패션      패션 스타일링 예술 바탕
# 1                         바탕 스타일 패션 수 패션 스타일링 개성 스타일             패션 스타일
# 2                     중 플라워 패턴 무드 플라워 패턴 도 플라워 패턴 매력         패션 스타일링 여행
# 3  플로럴 패턴 꽃 무늬 플로럴 패턴 중 크기 꽃 무늬 여성 분위기 연출 보 세 플로럴...             패션 스타일
# 4                        패션 스타일 스타일 마음 패션 개성 스타일 스타일       패션 패션 스타일리스트

# %%
# 결측치 제거
df = df.dropna(subset=['preprocessed_body'])
df.shape
# Out:
# (2928, 7)

# %%
# 상위 (max_features)개의 단어에 대해서만 vectorize  -> 각각의 문서들을 벡터 형태로 만들기 위해서 사용
# max_df=0.5: 문서의 절반 이상에서 나타나는 단어를 무시 -> 자주 등장하지만 정보량이 적은 단어 
vectorizer = TfidfVectorizer(max_features=80, max_df=0.5, smooth_idf=True) 
X = vectorizer.fit_transform(df['preprocessed_body'])

# %%
print(X.shape)
# Out:
# (2928, 80)

# %%
# X는 sparse matrix. 
# 효율적인 저장 방식인 CSR(Compressed Sparse Row) matrix 형식으로 저장되어 있음
X
# Out:
# <2928x80 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24873 stored elements in Compressed Sparse Row format>

# %% [markdown]
# - <span style = 'font-size:1.1em;line-height:1.5em'>TF-IDF의 각 차원의 의미</span>

# %%
terms = vectorizer.get_feature_names_out()
print(terms) # 벡터의 각 차원이 어떤 단어를 의미하는지 
print(len(terms)) # 총 벡터의 차원은 80차원
# Out:
# ['개성' '개인' '건강' '게임' '경제' '광고' '구매' '구축' '네일' '다양' '대하' '도시' '도전' '독특'
#  '디자인' '디지털' '레드' '맞춤' '매력' '메이크업' '모바일' '문화' '미국' '분위기' '뷰티' '브라운' '브랜드'
#  '블루' '사례' '선택' '수익' '스마트' '스타일' '스타일링' '스튜디오' '시장' '신발' '아트' '액세서리' '얼굴'
#  '여행' '연출' '염색' '영화' '온라인' '욕실' '음악' '인기' '인테리어' '일본' '일상' '자연' '작품' '적극'
#  '전통' '조명' '중국' '지속' '출처' '취향' '컬러' '코로나' '코리아' '콘텐츠' '클래식' '투자' '트렌드'
#  '트렌디' '패션' '포인트' '표현' '피부' '핑크' '한국' '헤어' '화이트' '화장품' '환경' '활용' '흐름']
# 80

# %% [markdown]
# - <span style = 'font-size:1.1em;line-height:1.5em'>TF-IDF matrix에 Truncated SVD를 적용하여 LSA 수행</span>
#     - <span style = 'font-size:1.1em;line-height:1.5em'>n_components = 토픽 수</span>
#     - <span style = 'font-size:1.1em;line-height:1.5em'>일반적으로 TF-IDF 특징 수의 5%에서 20% 사이의 값을 토픽 수로 설정
#
# #### **연도별 데이터 프레임을 합쳤기 때문에 각 연도별로 유의미한 차이가 있을 것이라고 생각하고 토픽 수를 3개로 진행**
# - 하지만 유의미한 차이는 없었음

# %%
model = TruncatedSVD(n_components=3, n_iter=100, random_state=42)  
## 연도별 데이터프레임을 합쳤기 때문에 14년, 23년, 24년으로 나눔
model.fit(X)
# Out:
# TruncatedSVD(n_components=3, n_iter=100, random_state=42)

# %% [markdown]
# $$X=U \Sigma V^{T} \approx U_{trunc} \Sigma_{trunc} V_{trunc}^{T}$$
# - <span style = 'font-size:1.2em;line-height:1.5em'>여기서 <code>result=model.transform(X)</code>: $U_{trunc} \Sigma_{trunc}$</span>
#     - <span style = 'font-size:1.1em;line-height:1.5em'>여러 문서를 특정 차원의 벡터로 (즉, n개 단어의 조합으로) 표현</span>
#     - <span style = 'font-size:1.1em;line-height:1.5em'>그러나, SVD를 활용하여 여러 문서를 특정 차원의 벡터로 (즉, n개 주제의 조합으로) 표현 </span>

# %%
result = model.transform(X)
print(result.shape)
# Out:
# (2928, 3)

# %%
result.shape
# Out:
# (2928, 3)

# %%
# 각 topic이 몇 개의 단어 조합으로 되어있는지
print(model.components_.shape)
print(model.components_)
# Out:
# (3, 80)
# [[ 6.66743176e-02  1.03203638e-01  8.14416579e-02  2.58342562e-02
#    1.10002153e-01  1.21929656e-02  7.99604056e-02  2.77049365e-02
#    1.84872755e-02  1.50479591e-01  1.55341440e-01  4.23587003e-02
#    3.43270203e-02  6.12173970e-02  2.47641128e-01  1.00259806e-01
#    3.46708959e-02  5.10185595e-02  7.03600825e-02  5.79908550e-02
#    2.35497658e-02  6.82258751e-02  4.49275901e-02  8.59956609e-02
#    6.10595403e-02  2.90039754e-02  1.47104518e-01  3.74114263e-02
#    2.58231292e-02  7.53301969e-02  1.37407365e-02  4.66725208e-02
#    2.82189915e-01  4.46026211e-02  8.76138639e-03  1.51493467e-01
#    3.73951660e-02  2.49267597e-02  5.29898617e-02  2.92354570e-02
#    4.06479212e-02  7.44267237e-02  3.62761161e-02  2.65593742e-02
#    6.00713986e-02  2.82107232e-02  1.85844811e-02  1.31450831e-01
#    1.42851324e-01  2.52085871e-02  2.84804102e-02  8.98650130e-02
#    2.59854588e-02  3.53226172e-02  3.05853662e-02  2.85486675e-02
#    2.22526929e-02  1.17350628e-01  6.59051533e-02  4.92042089e-02
#    3.26401101e-01  4.53278245e-02  3.08533393e-02  2.71492066e-02
#    4.84386571e-02  7.33296544e-02  5.15698842e-01  3.75145442e-02
#    3.39524563e-01  3.77381284e-02  4.49361874e-02  6.60337277e-02
#    3.83721163e-02  5.63741442e-02  1.24642498e-01  3.91941408e-02
#    1.97505100e-02  1.35835306e-01  1.53274178e-01  3.49098390e-02]
#  [ 4.94507242e-02 -1.02688810e-01 -6.23463511e-02 -3.21061627e-02
#   -1.83686499e-01 -9.91880328e-03 -7.53052908e-02 -4.16083600e-02
#    1.45246887e-02 -9.76180735e-02 -1.65897833e-01 -4.02398997e-02
#   -9.51285108e-03  4.87035132e-02  6.18561431e-02 -1.40386643e-01
#    4.06639668e-02 -4.64535614e-02  3.39820748e-02  4.75188049e-02
#   -3.29508530e-02 -8.15908815e-02 -5.57475852e-02  5.80313656e-02
#    2.06319055e-02  4.07245710e-02 -4.94889653e-02  2.74407328e-02
#   -3.07799192e-02 -3.67123413e-02 -2.18273146e-02 -3.89350611e-02
#    2.98180456e-01  8.29332685e-02  6.83923929e-04 -2.61051230e-01
#    2.90990397e-02  2.37319098e-03  5.15673393e-02  2.57083048e-02
#   -3.01781201e-02  1.29687715e-01  5.92636202e-02 -2.32955169e-02
#   -7.02812710e-02 -8.24548390e-03 -1.68834604e-02  1.30562649e-02
#    5.89378925e-03 -2.81196892e-02  1.50173594e-03  2.90419856e-02
#   -1.21109810e-02 -4.04730392e-02 -2.40602322e-02 -2.98699744e-03
#   -4.00915250e-02 -9.33780835e-02 -3.83872732e-02 -2.57675102e-02
#    4.72915795e-01 -5.36579285e-02 -4.67262346e-02 -3.53153775e-02
#    3.44854958e-02 -1.27573924e-01 -4.10098016e-01  2.88345987e-02
#    3.37052249e-01  5.01764908e-02 -3.73832236e-03  5.28216994e-02
#    3.92837544e-02 -7.02922746e-02  2.44593412e-01  2.29044378e-02
#   -4.34368203e-03 -1.10825878e-01 -1.31738910e-01 -3.51746037e-02]
#  [ 3.46589002e-02  1.29831338e-03 -1.76895962e-02  3.31826808e-03
#   -1.49195006e-02  8.69612614e-03  2.36089042e-02  3.65610271e-04
#   -2.47166505e-02  2.33049473e-03 -1.80682538e-02  8.74098128e-03
#    3.79877219e-03  2.41088137e-02  2.50741051e-02  8.60932798e-03
#   -3.96513691e-02 -1.06092841e-03 -2.91028458e-03 -9.90265304e-02
#    8.12188081e-04  9.12774464e-03 -1.16201903e-03 -2.19769995e-02
#   -7.99902901e-02 -5.35061955e-02  9.40309013e-02 -3.43672954e-02
#   -3.65436087e-03 -1.04923140e-02  5.20317916e-03  3.56482834e-03
#    2.78737938e-01  2.20192887e-02 -2.19216156e-04 -3.41515025e-03
#    3.44560324e-02 -9.04600412e-03  6.95016199e-02 -2.88667109e-02
#    2.38963420e-02  4.35633701e-04 -8.81172390e-02  6.80821570e-03
#    1.35447125e-02 -1.85521235e-02  2.69356105e-03  3.80317806e-02
#   -1.53766895e-01  2.42723863e-03  1.13080040e-02 -6.28749155e-02
#    2.72559143e-03 -1.79728536e-03  5.69827521e-03 -1.28590709e-02
#    3.95745410e-03  3.73039757e-02 -1.88910469e-02  1.15736834e-02
#   -5.51637197e-01  5.95284485e-03  1.86498321e-02  1.53236226e-02
#    4.54764577e-02 -1.04751331e-03 -1.21895220e-01  6.78670790e-03
#    6.46415861e-01  2.95540920e-03  1.29020986e-03 -1.31543235e-01
#   -2.04589454e-02  3.92042135e-03 -2.81589479e-01  7.14220110e-03
#   -1.44389372e-02  1.50973903e-02 -3.52792686e-02  6.98195237e-03]]

# %%
terms = vectorizer.get_feature_names_out()
print(terms) # 벡터의 각 차원이 어떤 단어를 의미하는지 (Each dimension is matched with which word)
print(len(terms)) # 총 벡터의 차원은 80차원 (Dimension: 80)
# Out:
# ['개성' '개인' '건강' '게임' '경제' '광고' '구매' '구축' '네일' '다양' '대하' '도시' '도전' '독특'
#  '디자인' '디지털' '레드' '맞춤' '매력' '메이크업' '모바일' '문화' '미국' '분위기' '뷰티' '브라운' '브랜드'
#  '블루' '사례' '선택' '수익' '스마트' '스타일' '스타일링' '스튜디오' '시장' '신발' '아트' '액세서리' '얼굴'
#  '여행' '연출' '염색' '영화' '온라인' '욕실' '음악' '인기' '인테리어' '일본' '일상' '자연' '작품' '적극'
#  '전통' '조명' '중국' '지속' '출처' '취향' '컬러' '코로나' '코리아' '콘텐츠' '클래식' '투자' '트렌드'
#  '트렌디' '패션' '포인트' '표현' '피부' '핑크' '한국' '헤어' '화이트' '화장품' '환경' '활용' '흐름']
# 80

# %%
model.components_[0].shape
# Out:
# (80,)

# %% [markdown]
# - <span style = 'font-size:1.2em;line-height:1.5em'>각 topic에 대해서 상위 10개의 큰 값을 갖는 단어를 출력하는 함수</span>

# %%
def get_keyword_by_topic(components, feature_name, n=10):
    for idx, topic in enumerate(components):
        sorted_keyword_idx = np.argsort(components[idx])[-1:-n-1:-1]
        sorted_keyword_result = [(feature_name[x], topic[x].round(4)) for x in sorted_keyword_idx]
        print(f'Topic {idx}: {sorted_keyword_result}')

# %%
get_keyword_by_topic(model.components_, terms)
# Out:
# Topic 0: [('트렌드', 0.5157), ('패션', 0.3395), ('컬러', 0.3264), ('스타일', 0.2822), ('디자인', 0.2476), ('대하', 0.1553), ('활용', 0.1533), ('시장', 0.1515), ('다양', 0.1505), ('브랜드', 0.1471)]
# Topic 1: [('컬러', 0.4729), ('패션', 0.3371), ('스타일', 0.2982), ('헤어', 0.2446), ('연출', 0.1297), ('스타일링', 0.0829), ('디자인', 0.0619), ('염색', 0.0593), ('분위기', 0.058), ('피부', 0.0528)]
# Topic 2: [('패션', 0.6464), ('스타일', 0.2787), ('브랜드', 0.094), ('액세서리', 0.0695), ('클래식', 0.0455), ('인기', 0.038), ('지속', 0.0373), ('개성', 0.0347), ('신발', 0.0345), ('디자인', 0.0251)]

# %% [markdown]
# # <b> 2. LDA(Latent Dirichlet Allocation)</b>

# %%
# preprocessed_body에 있는 단어를 리스트에 넣은 칼럼 생성
df['word_list'] = df['preprocessed_body'].apply(lambda x: x.split())

# %%
df['word_list'].value_counts()
# Out:
# word_list
# [수]                                                                                                                                                                                                                                                                                                                                                                                                                                                                               858
# [본문, 수]                                                                                                                                                                                                                                                                                                                                                                                                                                                                             5
# [패션, 스타일리스트, 은, 도전, 패션, 독창, 패션, 스타일링, 은, 관행, 독특, 스타일, 환영, 해, 스타일링, 독창, 고, 특별, 니, 모던, 매력, 중, 모던, 전통, 현대, 조화, 예술, 클래식, 아이템, 현대, 디자인, 조합, 독특, 세련, 스타일, 수, 패턴, 소재, 컬러, 만, 모던, 스타일, 창조, 텍스처, 환상, 텍스처, 스타일링, 해, 터틀넥, 퓨어, 소재, 푸, 레더, 소재, 조합, 텍스처, 텍스, 처, 성, 의상, 풍성, 소재, 독특, 스타일, 시선, 레이어드, 아름다움, 레이어드, 스타일, 인기, 해, 의상, 레이어링, 멋, 룩, 연출, 셔츠, 니트, 베스트, 재킷, 조합, 은, 레이어드, 룩, 보, 요, 겨울, 추위, 뿐, 라, 패션, 감각, 수, 컬러, 환상, 풍경, 컬러, 패션, 스타일링, 모노, ...]                                                  1
# [케이티, 차, 애슬레저, 트렌드, 대하, 테니스, 룩, 애슬레저, 애슬레저, 룩, 팁, 애슬레저룩, 운동복, 여가, 복, 합성어, 운동, 뿐, 라, 일상생활, 것, 수, 스타일, 테니스, 원피스, 스커트, 테니스, 원피스, 애슬레저, 테니스, 원피스, 스커트, 애슬레저룩, 트렌드, 중, 급부상, 테니스, 원피스, 애슬레저, 스포츠, 경계, 허물, 지, 운동, 일상, 생활, 스타일리시, 것, 착용, 수, 인기, 테니스, 원피스, 은, 일상복, 여름철, 아웃도어, 캐주얼, 모임, 도심, 속, 일상복, 인기, 테니스, 스커트, 애슬레저, 테니스, 치마, 속바지, 스타일, 인기, 트렌드, 중, 테니스, 스커트, 애슬레저, 캐주얼, 매치, 스니커즈, 매치, 일상복, 손색, 스포티, 룩, 액세서리, 활용, 선글라스, 헤어, 밴드, 크로스, 개성, 레이어, 링, 날씨, 테니스, 원피스, 위, 스웨터, 자켓, 레이어링, ...]      1
# [트렌드, 선도, 세미리프컷, 영광, 은, 세미, 리프, 컷, 시술, 후기, 분, 세미, 리프, 컷, 지, 궁금, 분, 터, 트렌드, 헤어스타일, 중, 세미, 리프, 컷, 중성, 분위기, 주, 얼굴, 슬림, 게, 것, 스타일, 다, 스타일, 시, 디테일, 두상, 얼굴, 형, 참고, 시술, 통, 하, 중성, 트렌디, 스타일, 시술, 전, 님, 모발, 상태, 진단, 후, 님, 머리카락, 건강, 스타일, 발자국, 만, 커트, 세미, 리프, 컷, 자연, 속, 트렌디, 데, 길, 무게감, 줄, 얼굴, 라인, 커트, 후, 마무리, 님, 원, 중성, 트렌디, 분위기, 번, 시술, 후기, 트렌드, 헤어스타일, 중성, 분위기, 상, 보완, 얼굴, 형, 슬림, 게, 게, 헤어, 스타일, 시, 다면, 헤어, 웨이, ...]                                                                      1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# [홈, 데코, 은, 의심, 여지, 진보, 창의, 관점, 수, 종류, 성, 수, 적, 틈새, 건축, 디자인, 측면, 홈, 데코, 아이디어, 천연, 대담, 혼합, 금속, 맥시멀리즘, 생체, 친화, 디자인, 지속, 환경, 개성, 자연, 욕구, 나무, 돌, 등나무, 천연, 흙, 분위기, 연출, 고, 파란색, 녹색, 노란색, 대담, 생동감, 역동, 홈, 데코, 금, 구리, 금속, 혼합, 수, 반면, 맥시멀리즘은, 스타일, 혼합, 일치, 개성, 수, 마지막, 생체, 친화, 디자인, 식물, 천연, 흙빛, 자연, 실내, 평온, 웰빙, 주, 벽지, 질감, 실내, 벽지, 방, 개성, 질감, 수, 평범, 단순, 역동, 고, 흥미, 롭, 수, 일부, 인기, 벽지, 질감, 기하학, 모양, 꽃, 모티프, 줄무늬, 추상, 디자인, 풀, ...]                                                              1
# [뷰티, 신, 핫, 눈, 뷰티, 은, 신, 핫, 뷰티, 눈, 시, 분, 스키, 비타민, 유기농, 스킨케어, 스키, 비타민, 뷰티, 강타, 예정, 스키, 비타민, 유기농, 원료, 스킨케어, 피부, 안전, 것, 작용, 적, 영양, 공급, 케미칼, 성분, 최소, 자연, 추출, 비타민, 성분, 피부, 작용, 피부, 컨디션, 주, 환경, 도, 친화, 지구, 환경, 스마트, 미러, 퍼스널, 메이크업, 조언, 화장, 도구, 거울, 메이크업, 결과물, 곤, 스마트, 미러, 스마트, 미러, 얼굴, 퍼스널, 메이크업, 조언, 독특, 얼굴, 스캔, 메이크업, 스타일, 컬러, 립스틱, 아이섀도, 우, 수, 개인, 피부, 톤, 피부, 타입, 맞춤, 형, 메이크업, 조언, 수, 뷰티, 블로거, 인기, 워터, 픽싱, 유, 분기, 립스틱, 워터, 픽싱, 립스틱, ...]                                                1
# [패션, 열정, 분, 분, 헤어, 컬러, 스타일, 변경, 고자, 은, 헤어, 멋, 헤어, 스타일, 포스팅, 헤어, 컬러, 스타일, 아쿠아, 헤어, 신선, 바다, 아쿠아, 헤어, 헤어, 컬러, 인기, 끄, 아쿠아, 헤어, 색조, 물결, 듯, 연출, 시원, 분위기, 주, 헤어, 컬러, 헤어, 스타일, 길, 파마, 웨이브, 헤어, 스타일, 스타일, 자연, 분위기, 연출, 수, 바다, 허니, 브라운, 허니, 브라운, 컬러, 인기, 컬러, 갈색, 톤, 베이스, 황금빛, 컬러, 얼굴, 매력, 주, 허니, 브라운, 컬러, 헤어, 스타일, 롱, 레이어드, 컷, 블로비, 컷, 스타일, 생동감, 연출, 수, 헤어, 컬러, 미소, 로즈, 골드, 세련, 분위기, 로즈, 골드, 인기, 컬러, 로즈, 골드, 핑크, 골드, 조화, 롭, 컬러, 세련, ...]                                                      1
# [블루, 뷰티, 은, 블루, 뷰티, 블루, 뷰티, 인기, 트렌디, 블루, 메이크업, 블루, 메이크업, 인기, 끄, 은, 블루, 아이섀도우, 블루, 메이크업, 퍼카, 블루, 컬러, 마스카라, 블루, 아이라이너, 인기, 끄, 블루, 아이섀도우, 연출, 보트, 아이라인, 독특, 메이크업, 스타일, 선사, 블루, 네일, 아트, 네일, 아트, 블루, 화제, 미디엄, 톤, 블루, 컬러, 네일, 아트, 인기, 끄, 그림자, 네일, 아트, 그라데이션, 스타일, 블루, 네일, 수, 화이트, 베이지, 컬러, 클래식, 분위기, 연출, 수, 블루, 헤어, 컬러, 이제, 블루, 헤어, 컬러, 독특, 스타일, 블루, 컬러, 개성, 헤어, 컬러, 로얄, 블루, 퍼시안, 블루, 애기, 블루, 블루, 톤, 인기, 그라데이션, 하이라이트, 스타일링, 블루, 스킨케어, 블루, 피부, 블루, 스킨케어, 인기, ...]                         1
# [코코펌, 미용실, 구영리, 주, 내년, 펌, 거, 가요, 트렌드, 내년도, 분, 초, 데, 배, 속, 펌, 환원, 열, 펌, 속, 화, 속도, 곱슬, 속도, 조절, 곘, 이외, 질, 연화, 수, 트렌드, 퍼, 재생, 트렌드, 퍼, 연화, 열펌, 펌제, 스타일, 수, 데, 볼륨, 연화, 연화, 단축, 수, 시술, 수, 수, 분연화연화열펌헤어성형복구전문코코펌미용실구영리, 점촌, 미용실, 울산, 미용실, 열, 펌, 전자책, 컬러, 열, 푸, 북, 스터디, 크리닉복구펌, 크리닉, 복구, 염색, 코코펌, 미용실, 울산광역시, 울주군, 범서읍, 점촌, 길, 호]                                                                                                                                                            1
# Name: count, Length: 2067, dtype: int64

# %%
lst = df['word_list'].apply(lambda words: [word for word in words if len(word) == 1])
lst
# word_list에서 한 글자인 단어 확인 -> 무의미하다고 판단
# Out:
# 0       [은, 은, 해, 고, 니, 중, 수, 만, 해, 푸, 처, 성, 해, 멋, 룩, ...
# 1       [은, 번, 은, 해, 은, 중, 룩, 보, 세, 룩, 수, 션, 룩, 분, 드, ...
# 2       [은, 팁, 룩, 것, 눈, 중, 도, 면, 은, 터, 링, 만, 도, 룩, 수, ...
# 3       [은, 번, 은, 해, 중, 팁, 데, 점, 수, 룩, 수, 톤, 수, 롭, 톱, ...
# 4       [은, 빛, 옷, 중, 글, 주, 고, 룩, 보, 세, 룩, 런, 중, 보, 세, ...
#                               ...
# 2923    [글, 기, 수, 중, 수, 수, 양, 질, 끄, 수, 차, 보, 수, 성, 적, ...
# 2924    [삶, 주, 니, 되, 형, 형, 은, 대, 대, 드, 형, 형, 데, 은, 수, ...
# 2925    [분, 룩, 룩, 룩, 룩, 룩, 룩, 룩, 앤, 룩, 룩, 런, 룩, 고, 고, ...
# 2926    [지, 것, 알, 되, 거, 수, 지, 면, 니, 수, 수, 수, 점, 성, 면, ...
# 2927    [주, 펌, 거, 분, 초, 데, 배, 속, 펌, 열, 펌, 속, 화, 곘, 질, ...
# Name: word_list, Length: 2928, dtype: object

# %%
# word_list에서 한 글자인 단어 삭제
df['word_list'] = df['word_list'].apply(lambda words: [word for word in words if len(word) > 1])
df['word_list'].value_counts()
# Out:
# word_list
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   858
# [본문]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   5
# [패션, 스타일리스트, 도전, 패션, 독창, 패션, 스타일링, 관행, 독특, 스타일, 환영, 스타일링, 독창, 특별, 모던, 매력, 모던, 전통, 현대, 조화, 예술, 클래식, 아이템, 현대, 디자인, 조합, 독특, 세련, 스타일, 패턴, 소재, 컬러, 모던, 스타일, 창조, 텍스처, 환상, 텍스처, 스타일링, 터틀넥, 퓨어, 소재, 레더, 소재, 조합, 텍스처, 텍스, 의상, 풍성, 소재, 독특, 스타일, 시선, 레이어드, 아름다움, 레이어드, 스타일, 인기, 의상, 레이어링, 연출, 셔츠, 니트, 베스트, 재킷, 조합, 레이어드, 겨울, 추위, 패션, 감각, 컬러, 환상, 풍경, 컬러, 패션, 스타일링, 모노, 컬러, 컬러풀, 아이템, 선명, 스타일, 연출, 컬러, 스타일, 활력, 시그니처, 스포티, 초대, 스포티, 패션, 운동화, 스포츠, 웨어, 스트릿, 스타일, 아이템, 세련, 스포티, ...]                                                 1
# [케이티, 애슬레저, 트렌드, 대하, 테니스, 애슬레저, 애슬레저, 애슬레저룩, 운동복, 여가, 합성어, 운동, 일상생활, 스타일, 테니스, 원피스, 스커트, 테니스, 원피스, 애슬레저, 테니스, 원피스, 스커트, 애슬레저룩, 트렌드, 급부상, 테니스, 원피스, 애슬레저, 스포츠, 경계, 허물, 운동, 일상, 생활, 스타일리시, 착용, 인기, 테니스, 원피스, 일상복, 여름철, 아웃도어, 캐주얼, 모임, 도심, 일상복, 인기, 테니스, 스커트, 애슬레저, 테니스, 치마, 속바지, 스타일, 인기, 트렌드, 테니스, 스커트, 애슬레저, 캐주얼, 매치, 스니커즈, 매치, 일상복, 손색, 스포티, 액세서리, 활용, 선글라스, 헤어, 밴드, 크로스, 개성, 레이어, 날씨, 테니스, 원피스, 스웨터, 자켓, 레이어링, 다양, 계절, 활용, 테니스, 스커트, 애슬레저, 트렌드, 일환, 다양, 연령대, 스타일, 지속, 스니커즈, 스니커즈, 나이키, 스니커즈, 필템, 비하, 패셔너블, ...]      1
# [트렌드, 선도, 세미리프컷, 영광, 세미, 리프, 시술, 후기, 세미, 리프, 궁금, 트렌드, 헤어스타일, 세미, 리프, 중성, 분위기, 얼굴, 슬림, 스타일, 스타일, 디테일, 두상, 얼굴, 참고, 시술, 중성, 트렌디, 스타일, 시술, 모발, 상태, 진단, 머리카락, 건강, 스타일, 발자국, 커트, 세미, 리프, 자연, 트렌디, 무게감, 얼굴, 라인, 커트, 마무리, 중성, 트렌디, 분위기, 시술, 후기, 트렌드, 헤어스타일, 중성, 분위기, 보완, 얼굴, 슬림, 헤어, 스타일, 다면, 헤어, 웨이, 강변, 영광, 영업시간, 전화, 서울시, 광진구, 아차산로, 무선, 인터넷, 서울, 페이, 남녀, 화장실, 구분, 의역, 출구, 직진, 도착, 대중교통, 구의역, 출구, 직진, 버스, 승차, 주민, 센터, 하차, 횡단보도, 건너, 우회전, 헤어, 웨이, 주차, 메가커피, 주차장, 만석, ...]                                                    1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# [데코, 의심, 여지, 진보, 창의, 관점, 종류, 틈새, 건축, 디자인, 측면, 데코, 아이디어, 천연, 대담, 혼합, 금속, 맥시멀리즘, 생체, 친화, 디자인, 지속, 환경, 개성, 자연, 욕구, 나무, 등나무, 천연, 분위기, 연출, 파란색, 녹색, 노란색, 대담, 생동감, 역동, 데코, 구리, 금속, 혼합, 반면, 맥시멀리즘은, 스타일, 혼합, 일치, 개성, 마지막, 생체, 친화, 디자인, 식물, 천연, 흙빛, 자연, 실내, 평온, 웰빙, 벽지, 질감, 실내, 벽지, 개성, 질감, 평범, 단순, 역동, 흥미, 일부, 인기, 벽지, 질감, 기하학, 모양, 모티프, 줄무늬, 추상, 디자인, 리넨과, 질감, 마감, 질감, 의심, 여지, 데코, 인쇄, 맞춤, 인터랙티브, 페이퍼, 페이퍼, 디자인, 소박, 뉴트럴, 컬러, 데코, 아이디어, 갈색, 녹색, 오렌지, 흙빛, ...]                                                                1
# [뷰티, 뷰티, 뷰티, 스키, 비타민, 유기농, 스킨케어, 스키, 비타민, 뷰티, 강타, 예정, 스키, 비타민, 유기농, 원료, 스킨케어, 피부, 안전, 작용, 영양, 공급, 케미칼, 성분, 최소, 자연, 추출, 비타민, 성분, 피부, 작용, 피부, 컨디션, 환경, 친화, 지구, 환경, 스마트, 미러, 퍼스널, 메이크업, 조언, 화장, 도구, 거울, 메이크업, 결과물, 스마트, 미러, 스마트, 미러, 얼굴, 퍼스널, 메이크업, 조언, 독특, 얼굴, 스캔, 메이크업, 스타일, 컬러, 립스틱, 아이섀도, 개인, 피부, 피부, 타입, 맞춤, 메이크업, 조언, 뷰티, 블로거, 인기, 워터, 픽싱, 분기, 립스틱, 워터, 픽싱, 립스틱, 워터, 지루, 유분, 수분, 제형, 입술, 발림, 피부, 컬러, 연출, 입술, 오랫동안, 지속, 건조, 입술, 예방, 수분, 선사, 유기농, 원료, ...]                                                            1
# [패션, 열정, 헤어, 컬러, 스타일, 변경, 고자, 헤어, 헤어, 스타일, 포스팅, 헤어, 컬러, 스타일, 아쿠아, 헤어, 신선, 바다, 아쿠아, 헤어, 헤어, 컬러, 인기, 아쿠아, 헤어, 색조, 물결, 연출, 시원, 분위기, 헤어, 컬러, 헤어, 스타일, 파마, 웨이브, 헤어, 스타일, 스타일, 자연, 분위기, 연출, 바다, 허니, 브라운, 허니, 브라운, 컬러, 인기, 컬러, 갈색, 베이스, 황금빛, 컬러, 얼굴, 매력, 허니, 브라운, 컬러, 헤어, 스타일, 레이어드, 블로비, 스타일, 생동감, 연출, 헤어, 컬러, 미소, 로즈, 골드, 세련, 분위기, 로즈, 골드, 인기, 컬러, 로즈, 골드, 핑크, 골드, 조화, 컬러, 세련, 분위기, 연출, 로즈, 골드, 컬러, 헤어, 스타일, 보브, 헤어, 스타일, 단발, 스타일링, 로즈, 골드, 컬러, 시크, ...]                                                                    1
# [블루, 뷰티, 블루, 뷰티, 블루, 뷰티, 인기, 트렌디, 블루, 메이크업, 블루, 메이크업, 인기, 블루, 아이섀도우, 블루, 메이크업, 퍼카, 블루, 컬러, 마스카라, 블루, 아이라이너, 인기, 블루, 아이섀도우, 연출, 보트, 아이라인, 독특, 메이크업, 스타일, 선사, 블루, 네일, 아트, 네일, 아트, 블루, 화제, 미디엄, 블루, 컬러, 네일, 아트, 인기, 그림자, 네일, 아트, 그라데이션, 스타일, 블루, 네일, 화이트, 베이지, 컬러, 클래식, 분위기, 연출, 블루, 헤어, 컬러, 이제, 블루, 헤어, 컬러, 독특, 스타일, 블루, 컬러, 개성, 헤어, 컬러, 로얄, 블루, 퍼시안, 블루, 애기, 블루, 블루, 인기, 그라데이션, 하이라이트, 스타일링, 블루, 스킨케어, 블루, 피부, 블루, 스킨케어, 인기, 블루, 로션, 크림, 마스크, 발매, 민감, 피부, 피부, 장벽, ...]                                                  1
# [코코펌, 미용실, 구영리, 내년, 가요, 트렌드, 내년도, 환원, 속도, 곱슬, 속도, 조절, 이외, 연화, 트렌드, 재생, 트렌드, 연화, 열펌, 펌제, 스타일, 볼륨, 연화, 연화, 단축, 시술, 분연화연화열펌헤어성형복구전문코코펌미용실구영리, 점촌, 미용실, 울산, 미용실, 전자책, 컬러, 스터디, 크리닉복구펌, 크리닉, 복구, 염색, 코코펌, 미용실, 울산광역시, 울주군, 범서읍, 점촌]                                                                                                                                                                                                                                                                                         1
# Name: count, Length: 2067, dtype: int64

# %%
from gensim import corpora

word_dict = corpora.Dictionary(df['word_list'])

# %%
corpus = [word_dict.doc2bow(text) for text in df['word_list']]

# %%
len(corpus)
# Out:
# 2928

# %%
corpus[2]  ## 2번째 문서에 대해 각각의 단어들이 몇 번을 나왔는지..
# Out:
# [(0, 1),
#  (1, 2),
#  (7, 1),
#  (12, 2),
#  (13, 2),
#  (14, 1),
#  (17, 2),
#  (20, 5),
#  (21, 1),
#  (28, 1),
#  (29, 2),
#  (30, 2),
#  (34, 2),
#  (35, 1),
#  (39, 1),
#  (46, 3),
#  (48, 2),
#  (54, 5),
#  (55, 5),
#  (59, 3),
#  (63, 1),
#  (67, 2),
#  (74, 1),
#  (80, 1),
#  (85, 1),
#  (90, 3),
#  (92, 1),
#  (93, 1),
#  (104, 1),
#  (105, 1),
#  (106, 1),
#  (107, 1),
#  (108, 1),
#  (109, 2),
#  (110, 1),
#  (111, 3),
#  (112, 1),
#  (113, 1),
#  (114, 2),
#  (115, 1),
#  (116, 1),
#  (117, 4),
#  (118, 1)]

# %%
[(idx,word) for idx, word in word_dict.items()]
# Out:
# [(0, '감각'),
#  (1, '개성'),
#  (2, '겨울'),
#  (3, '관행'),
#  (4, '니트'),
#  (5, '도전'),
#  (6, '독창'),
#  (7, '독특'),
#  (8, '디자인'),
#  (9, '레더'),
#  (10, '레이어드'),
#  (11, '레이어링'),
#  (12, '매력'),
#  (13, '모노'),
#  (14, '모던'),
#  (15, '베스트'),
#  (16, '선명'),
#  (17, '세련'),
#  (18, '셔츠'),
#  (19, '소재'),
#  (20, '스타일'),
#  (21, '스타일리스트'),
#  (22, '스타일링'),
#  (23, '스트릿'),
#  (24, '스포츠'),
#  (25, '스포티'),
#  (26, '시그니처'),
#  (27, '시선'),
#  (28, '아름다움'),
#  (29, '아이템'),
#  (30, '연출'),
#  (31, '예술'),
#  (32, '운동화'),
#  (33, '웨어'),
#  (34, '의상'),
#  (35, '인기'),
#  (36, '자유'),
#  (37, '재킷'),
#  (38, '전통'),
#  (39, '조합'),
#  (40, '조화'),
#  (41, '즐거움'),
#  (42, '창조'),
#  (43, '초대'),
#  (44, '추위'),
#  (45, '출발'),
#  (46, '컬러'),
#  (47, '컬러풀'),
#  (48, '클래식'),
#  (49, '탐구'),
#  (50, '터틀넥'),
#  (51, '텍스'),
#  (52, '텍스처'),
#  (53, '특별'),
#  (54, '패션'),
#  (55, '패턴'),
#  (56, '풍경'),
#  (57, '풍성'),
#  (58, '퓨어'),
#  (59, '현대'),
#  (60, '환상'),
#  (61, '환영'),
#  (62, '활기'),
#  (63, '활력'),
#  (64, '고급'),
#  (65, '고민'),
#  (66, '고전'),
#  (67, '과거'),
#  (68, '길거리'),
#  (69, '깔끔'),
#  (70, '도시'),
#  (71, '동반자'),
#  (72, '루즈'),
#  (73, '마켓'),
#  (74, '무드'),
#  (75, '미니멀'),
#  (76, '바탕'),
#  (77, '발전'),
#  (78, '발휘'),
#  (79, '보헤미안'),
#  (80, '분위기'),
#  (81, '빈티지'),
#  (82, '사랑'),
#  (83, '상점'),
#  (84, '스니커즈'),
#  (85, '스커트'),
#  (86, '스트리트'),
#  (87, '시점'),
#  (88, '심플'),
#  (89, '알리'),
#  (90, '액세서리'),
#  (91, '업데이트'),
#  (92, '열정'),
#  (93, '영감'),
#  (94, '온라인'),
#  (95, '인스피레'),
#  (96, '일부'),
#  (97, '자연'),
#  (98, '창의력'),
#  (99, '캐주얼'),
#  (100, '테일러'),
#  (101, '팔레트'),
#  (102, '플레어'),
#  (103, '플로럴'),
#  (104, '균형'),
#  (105, '레이어'),
#  (106, '모자'),
#  (107, '목걸이'),
#  (108, '선글라스'),
#  (109, '아우'),
#  (110, '여성'),
#  (111, '오버'),
#  (112, '자켓'),
#  (113, '코트'),
#  (114, '트렌디'),
#  (115, '펑키'),
#  (116, '포인트'),
#  (117, '플라워'),
#  (118, '흑백'),
#  (119, '귀걸이'),
#  (120, '라이프'),
#  (121, '레그'),
#  (122, '레트로'),
#  (123, '모노톤'),
#  (124, '무늬'),
#  (125, '미니'),
#  (126, '발견'),
#  (127, '베이직'),
#  (128, '부케'),
#  (129, '분방'),
#  (130, '블라우스'),
#  (131, '색감'),
#  (132, '스웨트'),
#  (133, '스키'),
#  (134, '스타'),
#  (135, '스트'),
#  (136, '시크'),
#  (137, '영혼'),
#  (138, '와이드'),
#  (139, '운동복'),
#  (140, '원피스'),
#  (141, '일상'),
#  (142, '자신감'),
#  (143, '재미'),
#  (144, '접목'),
#  (145, '주의'),
#  (146, '청바지'),
#  (147, '크기'),
#  (148, '팬츠'),
#  (149, '풍요'),
#  (150, '프린지'),
#  (151, '혼합'),
#  (152, '화이트'),
#  (153, '흰색'),
#  (154, '감성'),
#  (155, '검은색'),
#  (156, '누리'),
#  (157, '단색'),
#  (158, '대표'),
#  (159, '레이스'),
#  (160, '마음'),
#  (161, '매치'),
#  (162, '몽환'),
#  (163, '무한'),
#  (164, '믹스'),
#  (165, '소매'),
#  (166, '소통'),
#  (167, '순간'),
#  (168, '슈트'),
#  (169, '스웨터'),
#  (170, '스타일리시'),
#  (171, '슬랙스'),
#  (172, '아이콘'),
#  (173, '웨이'),
#  (174, '탐험'),
#  (175, '트렌치코트'),
#  (176, '티셔츠'),
#  (177, '퍼프'),
#  (178, '프릴'),
#  (179, '단정'),
#  (180, '대세'),
#  (181, '로맨틱'),
#  (182, '메이크업'),
#  (183, '문화'),
#  (184, '소프트'),
#  (185, '오늘날'),
#  (186, '옷장'),
#  (187, '완성도'),
#  (188, '유효'),
#  (189, '자유분방'),
#  (190, '조거'),
#  (191, '차지'),
#  (192, '취향'),
#  (193, '헤어스타일'),
#  (194, '감사'),
#  (195, '그래픽'),
#  (196, '다음'),
#  (197, '단계'),
#  (198, '레볼루션'),
#  (199, '매혹'),
#  (200, '미학'),
#  (201, '벨트'),
#  (202, '변화'),
#  (203, '부상'),
#  (204, '부활'),
#  (205, '샌들'),
#  (206, '신발'),
#  (207, '업그레이드'),
#  (208, '여행'),
#  (209, '열풍'),
#  (210, '완벽'),
#  (211, '전하'),
#  (212, '조각'),
#  (213, '집중'),
#  (214, '체크무늬'),
#  (215, '트랙수트'),
#  (216, '허리'),
#  (217, '각인'),
#  (218, '기억'),
#  (219, '꽃무늬'),
#  (220, '대조'),
#  (221, '두각'),
#  (222, '두껍'),
#  (223, '머리'),
#  (224, '머리띠'),
#  (225, '밴드'),
#  (226, '본인'),
#  (227, '부각'),
#  (228, '사이'),
#  (229, '색채'),
#  (230, '신선'),
#  (231, '용도'),
#  (232, '인상'),
#  (233, '자아'),
#  (234, '장식'),
#  (235, '클립'),
#  (236, '헤어'),
#  (237, '화제'),
#  (238, '흔적'),
#  (239, '년도'),
#  (240, '방식'),
#  (241, '벨벳'),
#  (242, '부츠'),
#  (243, '슈즈'),
#  (244, '일리'),
#  (245, '정점'),
#  (246, '정중'),
#  (247, '중립'),
#  (248, '최적'),
#  (249, '크림'),
#  (250, '트랙'),
#  (251, '트렌치'),
#  (252, '펌프스나'),
#  (253, '페미닌'),
#  (254, '플랫'),
#  (255, '필수품'),
#  (256, '가죽'),
#  (257, '단조'),
#  (258, '생기'),
#  (259, '실험'),
#  (260, '패밀리'),
#  (261, '포커스'),
#  (262, '흐름'),
#  (263, '감독'),
#  (264, '감동'),
#  (265, '개봉'),
#  (266, '개인'),
#  (267, '결말'),
#  (268, '관객'),
#  (269, '관람'),
#  (270, '권리'),
#  (271, '극장'),
#  (272, '긴장감'),
#  (273, '냄새'),
#  (274, '놀런'),
#  (275, '도장'),
#  (276, '동질감'),
#  (277, '러닝'),
#  (278, '롯데시네마'),
#  (279, '마이클'),
#  (280, '매튜'),
#  (281, '맥커너히'),
#  (282, '메가박스'),
#  (283, '몰입'),
#  (284, '무시'),
#  (285, '문제'),
#  (286, '반전'),
#  (287, '보호원'),
#  (288, '불구'),
#  (289, '브라운관'),
#  (290, '상영관'),
#  (291, '선사'),
#  (292, '세상'),
#  (293, '소리'),
#  (294, '소송'),
#  (295, '수록'),
#  (296, '스케일'),
#  (297, '스토리'),
#  (298, '슬픔'),
#  (299, '실망'),
#  (300, '아들'),
#  (301, '아빠'),
#  (302, '아침'),
#  (303, '여배우'),
#  (304, '연기'),
#  (305, '영화'),
#  (306, '요즘'),
#  (307, '음료수'),
#  (308, '음식'),
#  (309, '음식물'),
#  (310, '이름값'),
#  (311, '이벤트'),
#  (312, '이외'),
#  (313, '이틀'),
#  (314, '인간'),
#  (315, '인터뷰'),
#  (316, '인터스텔라'),
#  (317, '인하'),
#  (318, '일정'),
#  (319, '작품'),
#  (320, '장대'),
#  (321, '장면'),
#  (322, '재앙'),
#  (323, '제기'),
#  (324, '제시카'),
#  (325, '제지'),
#  (326, '조조'),
#  (327, '주인공'),
#  (328, '줄거리'),
#  (329, '지구'),
#  (330, '지루'),
#  (331, '직원'),
#  (332, '직접'),
#  (333, '차스테인'),
#  (334, '출연'),
#  (335, '침해'),
#  (336, '캐릭터'),
#  (337, '크리스토퍼'),
#  (338, '타임'),
#  (339, '트릭'),
#  (340, '판례'),
#  (341, '팝콘'),
#  (342, '평일'),
#  (343, '평택'),
#  (344, '할리우드'),
#  (345, '할인'),
#  (346, '해서웨이'),
#  (347, '현실'),
#  (348, '화면'),
#  (349, '환경'),
#  (350, '가능스트'),
#  (351, '계절'),
#  (352, '고요'),
#  (353, '데님'),
#  (354, '스트라이프'),
#  (355, '아우터'),
#  (356, '영원'),
#  (357, '옷차림'),
#  (358, '워싱으'),
#  (359, '제작'),
#  (360, '착용감'),
#  (361, '최고'),
#  (362, '팔찌'),
#  (363, '공존'),
#  (364, '스웨트셔츠'),
#  (365, '여성미'),
#  (366, '연령'),
#  (367, '진화'),
#  (368, '통합'),
#  (369, '가을'),
#  (370, '감상'),
#  (371, '강세'),
#  (372, '결혼'),
#  (373, '공식'),
#  (374, '군더더기'),
#  (375, '글래머스'),
#  (376, '넥라인'),
#  (377, '대신'),
#  (378, '디자이너'),
#  (379, '레전드'),
#  (380, '렌타'),
#  (381, '로모'),
#  (382, '륄리에'),
#  (383, '리나'),
#  (384, '리비니'),
#  (385, '마케자'),
#  (386, '모니크'),
#  (387, '모티브'),
#  (388, '바이'),
#  (389, '박람회'),
#  (390, '베라'),
#  (391, '부분'),
#  (392, '산체스'),
#  (393, '상상'),
#  (394, '섹시'),
#  (395, '순백'),
#  (396, '스튜디오'),
#  (397, '시스루'),
#  (398, '신부'),
#  (399, '아이보리'),
#  (400, '아크라'),
#  (401, '안정감'),
#  (402, '암살'),
#  (403, '엑스'),
#  (404, '엔젤'),
#  (405, '예비'),
#  (406, '오스카'),
#  (407, '오픈'),
#  (408, '원단'),
#  (409, '웨딩'),
#  (410, '웨딩드레스'),
#  (411, '이어'),
#  (412, '장미'),
#  (413, '정서'),
#  (414, '제한'),
#  (415, '준비'),
#  (416, '캐롤'),
#  (417, '컬렉션'),
#  (418, '케네스'),
#  (419, '케바자'),
#  (420, '콜렉션'),
#  (421, '크리스'),
#  (422, '토스'),
#  (423, '파격'),
#  (424, '파악'),
#  (425, '헤레라'),
#  (426, '화보'),
#  (427, '센스'),
#  (428, '시원'),
#  (429, '악세사리'),
#  (430, '악센트'),
#  (431, '여름철'),
#  (432, '유니크'),
#  (433, '응원'),
#  (434, '재치'),
#  (435, '정상'),
#  (436, '도구'),
#  (437, '도트'),
#  (438, '라인'),
#  (439, '만남'),
#  (440, '블로킹'),
#  (441, '여유'),
#  (442, '조언'),
#  (443, '체크'),
#  (444, '추가'),
#  (445, '프린세스'),
#  (446, '흥미'),
#  (447, '강타'),
#  (448, '공유'),
#  (449, '기원'),
#  (450, '드레이프'),
#  (451, '린넨'),
#  (452, '민트'),
#  (453, '바지'),
#  (454, '방문'),
#  (455, '블로그'),
#  (456, '비비드'),
#  (457, '생동감'),
#  (458, '옐로우'),
#  (459, '유용'),
#  (460, '치마'),
#  (461, '통기'),
#  (462, '행복'),
#  (463, '향기'),
#  (464, '그해'),
#  (465, '대담'),
#  (466, '도래'),
#  (467, '반짝임'),
#  (468, '아트'),
#  (469, '정자'),
#  (470, '플로랄'),
#  (471, '극대'),
#  (472, '리메이크'),
#  (473, '물건'),
#  (474, '베이스볼'),
#  (475, '시절'),
#  (476, '전적'),
#  (477, '정수'),
#  (478, '초월'),
#  (479, '경력'),
#  (480, '경제'),
#  (481, '기본'),
#  (482, '나가'),
#  (483, '능력'),
#  (484, '니즈'),
#  (485, '런웨이'),
#  (486, '만족'),
#  (487, '맞춤'),
#  (488, '매체'),
#  (489, '배우'),
#  (490, '성공'),
#  (491, '수집'),
#  (492, '스킬'),
#  (493, '실크'),
#  (494, '업무'),
#  (495, '오렌지'),
#  (496, '임무'),
#  (497, '자격증'),
#  (498, '제안'),
#  (499, '조사'),
#  (500, '주시'),
#  (501, '지속'),
#  (502, '취득'),
#  (503, '크리에이팅'),
#  (504, '키우'),
#  (505, '필수'),
#  (506, '핑크'),
#  (507, '함양'),
#  (508, '향상'),
#  (509, '협력'),
#  (510, '혼용'),
#  (511, '먼저'),
#  (512, '얼굴'),
#  (513, '예전'),
#  (514, '다면'),
#  (515, '레트'),
#  (516, '만끽'),
#  (517, '스카프'),
#  (518, '의류'),
#  (519, '전달'),
#  (520, '추구'),
#  (521, '그레이'),
#  (522, '블루'),
#  (523, '소화'),
#  (524, '핑크와'),
#  (525, '가족'),
#  (526, '각본'),
#  (527, '공중'),
#  (528, '공중파'),
#  (529, '과속스캔들'),
#  (530, '광해'),
#  (531, '김수현'),
#  (532, '도둑'),
#  (533, '도둑들'),
#  (534, '동명'),
#  (535, '리스트'),
#  (536, '명절'),
#  (537, '민족'),
#  (538, '방영'),
#  (539, '부담감'),
#  (540, '선물'),
#  (541, '슈퍼배드'),
#  (542, '스타워즈'),
#  (543, '시기'),
#  (544, '시리즈'),
#  (545, '아바타'),
#  (546, '아이언맨'),
#  (547, '안방'),
#  (548, '어벤저스'),
#  (549, '엊그제'),
#  (550, '에피소드'),
#  (551, '연속'),
#  (552, '연휴'),
#  (553, '열연'),
#  (554, '영화관'),
#  (555, '와중'),
#  (556, '원작'),
#  (557, '웹툰'),
#  (558, '이름'),
#  (559, '자체'),
#  (560, '장르'),
#  (561, '장점'),
#  (562, '주가'),
#  (563, '주연'),
#  (564, '최종'),
#  (565, '케이블'),
#  (566, '코앞'),
#  (567, '특선'),
#  (568, '티브이'),
#  (569, '편성'),
#  (570, '홀로서기'),
#  (571, '흥행'),
#  (572, '흥행작'),
#  (573, '눈길'),
#  (574, '도배'),
#  (575, '마스터'),
#  (576, '묘미'),
#  (577, '발산'),
#  (578, '안성맞춤'),
#  (579, '제시'),
#  (580, '조명'),
#  (581, '중점'),
#  (582, '황금'),
#  (583, '거리'),
#  (584, '격식'),
#  (585, '겸비'),
#  (586, '미니멀리즘과'),
#  (587, '변신'),
#  (588, '부여'),
#  (589, '셔닝'),
#  (590, '순수'),
#  (591, '언급'),
#  (592, '주도'),
#  (593, '참고'),
#  (594, '최대'),
#  (595, '독보'),
#  (596, '바람'),
#  (597, '볼드'),
#  (598, '상징'),
#  (599, '식물'),
#  (600, '주황색'),
#  (601, '착용자'),
#  (602, '가미'),
#  (603, '각양각색'),
#  (604, '궁금'),
#  (605, '뉴발란스'),
#  (606, '덕분'),
#  (607, '론칭'),
#  (608, '리미티드'),
#  (609, '맨투맨'),
#  (610, '민감'),
#  (611, '바람막이'),
#  (612, '버전'),
#  (613, '성인'),
#  (614, '세트'),
#  (615, '슈퍼맨'),
#  (616, '스포트라이트'),
#  (617, '실용'),
#  (618, '어른'),
#  (619, '엄마'),
#  (620, '이미지'),
#  (621, '자랑'),
#  (622, '작년'),
#  (623, '중순'),
#  (624, '쪽지'),
#  (625, '캡처'),
#  (626, '퀼리티'),
#  (627, '키즈'),
#  (628, '키즈화'),
#  (629, '패셔너블'),
#  (630, '학기'),
#  (631, '눈부시웠'),
#  (632, '리즈'),
#  (633, '미니멀리즘'),
#  (634, '서리'),
#  (635, '절정'),
#  (636, '제격'),
#  (637, '프레피'),
#  (638, '플로우'),
#  (639, '대상'),
#  (640, '마법사'),
#  (641, '목적'),
#  (642, '미소'),
#  (643, '민낯'),
#  (644, '브랜드'),
#  (645, '비밀'),
#  (646, '슈팅'),
#  (647, '이해'),
#  (648, '지식'),
#  (649, '캠페인'),
#  (650, '컨설팅'),
#  (651, '파운데이션'),
#  (652, '프린트'),
#  (653, '피부'),
#  (654, '활약'),
#  (655, '상의'),
#  (656, '스포티한'),
#  (657, '트랜드'),
#  (658, '그린'),
#  (659, '네온'),
#  (660, '쇼핑'),
#  (661, '작성'),
#  (662, '적극'),
#  (663, '주자'),
#  (664, '대칭'),
#  (665, '리즘'),
#  (666, '미니멀리즘의'),
#  (667, '신축'),
#  (668, '정교'),
#  (669, '축제'),
#  (670, '카주얼'),
#  (671, '포스트모던'),
#  (672, '가장'),
#  (673, '걸음'),
#  (674, '검색'),
#  (675, '결과물'),
#  (676, '공방'),
#  (677, '광범위'),
#  (678, '구체'),
#  (679, '극복'),
#  (680, '나무'),
#  (681, '년핫트렌드호모프롬프트'),
#  (682, '답변'),
#  (683, '대체'),
#  (684, '대화'),
#  (685, '대화법'),
#  (686, '명령어'),
#  (687, '모델'),
#  (688, '모드'),
#  (689, '반면'),
#  (690, '범위'),
#  (691, '비판'),
#  (692, '사건'),
#  (693, '사고'),
#  (694, '사고방식'),
#  (695, '사용법'),
#  (696, '사용자'),
#  (697, '사항'),
#  (698, '생성'),
#  (699, '설명'),
#  (700, '세계사'),
#  (701, '세부'),
#  (702, '수행'),
#  (703, '신뢰'),
#  (704, '안녕'),
#  (705, '어로'),
#  (706, '언어'),
#  (707, '예시'),
#  (708, '옥수'),
#  (709, '온도'),
#  (710, '요약'),
#  (711, '요청'),
#  (712, '원리'),
#  (713, '위험'),
#  (714, '유익'),
#  (715, '의견'),
#  (716, '인공'),
#  (717, '인공지능'),
#  (718, '인공지능프롬프트활용꿀팁'),
#  (719, '인터넷'),
#  (720, '일본'),
#  (721, '자연어'),
#  (722, '작동'),
#  (723, '작업'),
#  (724, '장단점'),
#  (725, '전환'),
#  (726, '정리'),
#  (727, '정의'),
#  (728, '정확'),
#  (729, '조절'),
#  (730, '주제'),
#  (731, '지능'),
#  (732, '질문'),
#  (733, '출력'),
#  (734, '코리아'),
#  (735, '텍스트'),
#  (736, '트렌트'),
#  (737, '프롬'),
#  (738, '프롬프'),
#  (739, '프롬프트'),
#  (740, '프롬프트를'),
#  (741, '한계'),
#  (742, '해결'),
#  (743, '핵융합'),
#  (744, '행동'),
#  (745, '호모'),
#  (746, '블레이저'),
#  (747, '스웻셔츠'),
#  (748, '스터드'),
#  (749, '에센스'),
#  (750, '엣지'),
#  (751, '옵션'),
#  (752, '정장'),
#  (753, '트위드'),
#  (754, '헤리티지'),
#  (755, '휴가'),
#  (756, '연결'),
#  (757, '모험'),
#  (758, '완성'),
#  (759, '자연미'),
#  (760, '종류'),
#  (761, '활보'),
#  (762, '고자'),
#  (763, '슬립'),
#  (764, '정석'),
#  (765, '휴양지'),
#  (766, '높이'),
#  (767, '리츠'),
#  (768, '명품'),
#  (769, '비결'),
#  (770, '시계'),
#  (771, '층층'),
#  (772, '코디'),
#  (773, '플리츠'),
#  (774, '가디건'),
#  (775, '검정'),
#  (776, '기념'),
#  (777, '더위'),
#  (778, '몸매'),
#  (779, '신경'),
#  (780, '플레인'),
#  (781, '글로벌'),
#  (782, '김영주'),
#  (783, '노매드'),
#  (784, '루프'),
#  (785, '마무리'),
#  (786, '새해'),
#  (787, '안경'),
#  (788, '용어'),
#  (789, '이용'),
#  (790, '정신'),
#  (791, '지니'),
#  (792, '체형'),
#  (793, '타이트'),
#  (794, '탈피'),
#  (795, '트라이바'),
#  (796, '탐색'),
#  (797, '뒤흔'),
#  (798, '러프'),
#  (799, '러플'),
#  (800, '리뷰'),
#  (801, '미디'),
#  (802, '세련미'),
#  (803, '유명'),
#  (804, '매료'),
#  (805, '성취감'),
#  (806, '만능'),
#  (807, '사이즈'),
#  (808, '어깨'),
#  (809, '예외'),
#  (810, '착용'),
#  (811, '파티'),
#  (812, '화룡점정'),
#  (813, '관점'),
#  (814, '구현'),
#  (815, '논의'),
#  (816, '보유'),
#  (817, '비전'),
#  (818, '역량'),
#  (819, '이해력'),
#  (820, '주얼'),
#  (821, '투자'),
#  (822, '검정색'),
#  (823, '글래머러스'),
#  (824, '남성'),
#  (825, '독자'),
#  (826, '비즈'),
#  (827, '에너지'),
#  (828, '회색'),
#  (829, '가요'),
#  (830, '개념'),
#  (831, '계정'),
#  (832, '노멀'),
#  (833, '미디어'),
#  (834, '블로거'),
#  (835, '소셜'),
#  (836, '정지'),
#  (837, '코어'),
#  (838, '플랫폼'),
#  (839, '플루'),
#  (840, '그림'),
#  (841, '존재'),
#  (842, '데뷔'),
#  (843, '방탄소년단'),
#  (844, '세븐'),
#  (845, '스트레이'),
#  (846, '엑소'),
#  (847, '엔터테인먼트'),
#  (848, '여자'),
#  (849, '여자아이'),
#  (850, '큐브'),
#  (851, '투모로우바이투게더'),
#  (852, '트와이스'),
#  (853, '하이브'),
#  (854, '고유'),
#  (855, '도도'),
#  (856, '칙스'),
#  (857, '현재'),
#  (858, '과장'),
#  (859, '내구'),
#  (860, '이제'),
#  (861, '전개'),
#  (862, '정제'),
#  (863, '차이'),
#  (864, '추세'),
#  (865, '추억'),
#  (866, '품질'),
#  (867, '다리'),
#  (868, '데이트'),
#  (869, '모임'),
#  (870, '무관'),
#  (871, '변형'),
#  (872, '아이코닉한'),
#  (873, '역동'),
#  (874, '외출'),
#  (875, '적합'),
#  (876, '지금'),
#  (877, '특유'),
#  (878, '다층'),
#  (879, '밑단'),
#  (880, '컴백'),
#  (881, '계기'),
#  (882, '맞이'),
#  (883, '모색'),
#  (884, '미니멀리즘이'),
#  (885, '염두'),
#  (886, '접근'),
#  (887, '지향'),
#  (888, '퀄리티'),
#  (889, '보헴'),
#  (890, '안내'),
#  (891, '자수'),
#  (892, '존중'),
#  (893, '지난해'),
#  (894, '캡슐'),
#  (895, '클라이언트'),
#  (896, '패스트'),
#  (897, '균형감'),
#  (898, '무대'),
#  (899, '변주'),
#  (900, '아우터가'),
#  (901, '중시'),
#  (902, '질주'),
#  (903, '겨울철'),
#  (904, '날씨'),
#  (905, '숙지'),
#  (906, '이해도'),
#  (907, '메인'),
#  (908, '양상'),
#  (909, '담당'),
#  (910, '스트릿웨어'),
#  (911, '에디토리얼'),
#  (912, '용이'),
#  (913, '인물'),
#  (914, '인정'),
#  (915, '가스파르'),
#  (916, '고혹'),
#  (917, '고흐'),
#  (918, '공예'),
#  (919, '남자'),
#  (920, '노라노'),
#  (921, '다큐'),
#  (922, '동성애'),
#  (923, '드라마'),
#  (924, '디렉터'),
#  (925, '디올'),
#  (926, '라면'),
#  (927, '레니'),
#  (928, '레아'),
#  (929, '로랑'),
#  (930, '루이스'),
#  (931, '몬드리안'),
#  (932, '발레리'),
#  (933, '발렌티노'),
#  (934, '베르트랑'),
#  (935, '보렐로이며'),
#  (936, '브루니'),
#  (937, '사례'),
#  (938, '생로'),
#  (939, '생로랑'),
#  (940, '샤넬'),
#  (941, '선도'),
#  (942, '세기'),
#  (943, '세이두'),
#  (944, '수석'),
#  (945, '수정'),
#  (946, '스모'),
#  (947, '실력'),
#  (948, '싫증'),
#  (949, '싱크'),
#  (950, '앤디'),
#  (951, '업적'),
#  (952, '역사'),
#  (953, '연기력'),
#  (954, '예고편'),
#  (955, '오뜨꾸뛰르'),
#  (956, '우리나라'),
#  (957, '울리엘'),
#  (958, '워홀'),
#  (959, '유래'),
#  (960, '율리'),
#  (961, '이브'),
#  (962, '인생'),
#  (963, '재단'),
#  (964, '제레미'),
#  (965, '찬사'),
#  (966, '찰떡궁합'),
#  (967, '천재'),
#  (968, '초점'),
#  (969, '코코'),
#  (970, '턱시도'),
#  (971, '통찰'),
#  (972, '파워'),
#  (973, '파트너십'),
#  (974, '패션쇼'),
#  (975, '평가'),
#  (976, '포스터'),
#  (977, '프랑스'),
#  (978, '피카소'),
#  (979, '하우스'),
#  (980, '회자'),
#  (981, '가입'),
#  (982, '거래소'),
#  (983, '거부감'),
#  (984, '결정'),
#  (985, '경각심'),
#  (986, '공기업'),
#  (987, '공무'),
#  (988, '공무원'),
#  (989, '공시'),
#  (990, '공포'),
#  (991, '과대'),
#  (992, '구글'),
#  (993, '구매'),
#  (994, '구조'),
#  (995, '국가'),
#  (996, '규정'),
#  (997, '그룹'),
#  (998, '그린워싱'),
#  (999, '금융'),
#  ...]

# %% [markdown]
# ## LDA 모델 훈련 (Topic 수: 3개로 설정)

# %%
import gensim

# %%
N_TOPICS = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus, 
                                           num_topics = N_TOPICS,  ## 주제 몇개할 건지
                                           id2word=word_dict)   ## 보카뷸러리 셋

# %% [markdown]
# ### 각 topic의 대표 단어들을 출력

# %%
topics = ldamodel.print_topics(num_words=10)  ## 각 토픽들에 대해서 몇 개의 단어(num_words)로 표현할 것인지
## 대표적인 단어를 알 수 있음
for topic in topics:
    print(topic)
# Out:
# (0, '0.015*"트렌드" + 0.015*"디자인" + 0.014*"시장" + 0.008*"패션" + 0.008*"스타일" + 0.007*"대하" + 0.007*"투자" + 0.007*"욕실" + 0.005*"다양" + 0.005*"디지털"')
# (1, '0.032*"트렌드" + 0.010*"대하" + 0.009*"활용" + 0.009*"환경" + 0.008*"다양" + 0.008*"시장" + 0.007*"지속" + 0.006*"개인" + 0.006*"브랜드" + 0.006*"디자인"')
# (2, '0.033*"컬러" + 0.019*"트렌드" + 0.017*"스타일" + 0.011*"패션" + 0.011*"피부" + 0.009*"헤어" + 0.009*"메이크업" + 0.009*"디자인" + 0.009*"뷰티" + 0.008*"인테리어"')

# %% [markdown]
# ## LDA 시각화

# %%
from IPython.core.display import HTML
import pyLDAvis
from pyLDAvis import gensim_models

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(ldamodel, corpus, word_dict)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1644020426016645762686411745" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el1644020426016645762686411745_data = {"mdsDat": {"x": [-0.06696019982716797, 0.1082140383191884, -0.041253838492020425], "y": [0.035367636274840825, 0.0060827333407531756, -0.041450369615594], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [39.512614454381115, 33.022723765165225, 27.464661780453664]}, "tinfo": {"Term": ["\uceec\ub7ec", "\ud53c\ubd80", "\uba54\uc774\ud06c\uc5c5", "\ud5e4\uc5b4", "\uc2a4\ud0c0\uc77c", "\ubdf0\ud2f0", "\uc2dc\uc7a5", "\uc695\uc2e4", "\uc5fc\uc0c9", "\ud22c\uc790", "\uc74c\uc545", "\ub514\uc790\uc778", "\ud53c\uce58", "\ub124\uc77c", "\ube0c\ub77c\uc6b4", "\uacbd\uc81c", "\ub808\ub4dc", "\ub514\uc9c0\ud138", "\ubd84\uc704\uae30", "\uacf5\uc5f0", "\ub300\ud558", "\uc5bc\uad74", "\ud328\uc158", "\ube14\ub8e8", "\uc544\ud2b8", "\ucc44\uc6a9", "\uc8fc\uc5bc\ub9ac", "\ud658\uacbd", "\ud551\ud06c", "\ud37c\uc988", "\uc5b8\ub354\uc544\uba38", "\ud761\uc785", "\uc787\ubab8", "\uc120\ubd88", "\ube14\ub799\ubc15\uc2a4", "\uc2a4\uce74\uc774\uc2a4\uce90\ub108", "\uc0dd\ud1a0", "\ub3c4\ubc30", "\uc774\ube44\uc2a4\ud5e4\uc5b4", "\ub514\uc544\uc9c0\uc624", "\uad50\uc2dc", "\ub0b4\ube44\uac8c\uc774\uc158", "\uc774\ucf54\ub178\ub7ed\uc2a4", "\uae40\uc6a9\ud55c", "\uc720\uc2ec", "\ud638\uc57c", "\uceec\ub7fc", "\ubbf8\ub77c\ud074", "\uc778\ud154", "\uc5ec\ud589\uac1d", "\ubaa9\uc801\uc9c0", "\ucf8c\ub77d", "\uae40\uc6a9\ud558", "\ub8e8\uc2dc", "\uce21\uc704", "\ub611\ub2e5", "\ucf8c\ub77d\uc8fc\uc758", "\uc804\ub2f4", "\ud2b8\ub808\ud0b9", "\ube14\ub808\uc800", "\ud504\ub86c\ud504\ud2b8", "\uace0\ub4f1", "\ub9ac\ud034\ub4dc\ud3f4\ub9ac", "\ud544\ub77c\ud14c\uc2a4", "\ud638\ubaa8", "\uc678\uc2dd\uc5c5", "\ub3c4\ud30c\ubc0d", "\uc724\ucef4\uc988", "\uc624\ud504", "\ub514\ud1a0", "\ubc84\ub77c\uc774\uc5b4\ud2f0", "\uc2a4\ud540", "\uc0c1\uad8c", "\uc721\uac01", "\uc5ec\ud589", "\uc74c\uc131", "\ub3c4\ud30c\ubbfc", "\uc678\uc2dd", "\ud658\uacbd", "\ud074\ub77c\uc6b0\ub4dc", "\uc9c1\uc6d0", "\uacbd\uc81c", "\uc544\ube60", "\uc2a4\ub9c8\ud2b8", "\ud2b8\ub80c\ub4dc", "\uac1c\uc778", "\uc9c0\uc18d", "\ub300\ud558", "\ud65c\uc6a9", "\uc6b4\ub3d9", "\uad00\uad11", "\ub9de\ucda4", "\ub514\uc9c0\ud138", "\ub2e4\uc591", "\uac74\uac15", "\ubaa8\ubc14\uc77c", "\ube0c\ub79c\ub4dc", "\uc2dc\uc7a5", "\ubb38\ud654", "\uc778\ud14c\ub9ac\uc5b4", "\uad6c\ub9e4", "\uc628\ub77c\uc778", "\uc120\ud0dd", "\uac8c\uc784", "\uc778\uae30", "\ub514\uc790\uc778", "\ud328\uc158", "\ud55c\uad6d", "\uc790\uc5f0", "\uc870\uba85", "\uc77c\ubcf8", "\ubbf8\uad6d", "\ud22c\uc790", "\uc2a4\ud0c0\uc77c", "\ucd9c\ucc98", "\uceec\ub7ec", "\ubcf4\ube0c", "\ud0c0\ud22c", "\ub77c\uc774\ud130", "\ub514\ud50c\ub85c\ub9c8", "\uc19c\ube0c\ub808", "\uc9c4\ub2e8\uae30", "\ub9d0\ubcf8", "\uae40\uc9c0\uc601", "\uc5fc\uc0c9", "\ud53c\ubd80\uacfc", "\ube14\ub7ec", "\uc9c0\ud3ec\uc5b4", "\ud074\ub80c\uc9d5", "\ube0c\ub85c\uc6b0", "\uc544\ub9c8\uc774\ub4dc", "\uc131\ud615\uc678\uacfc", "\ubc14\ub2d0\ub77c", "\uc544\ud06c\ub124", "\ubaa8\uc774\uc2a4\ucc98", "\ub9cc\ucd0c\ub3d9", "\uad11\ucc44", "\uc2dc\uc5b4", "\ucfe8\ud1a4", "\ubba4\ud2b8", "\uce90\ub7ec\uba5c", "\ub208\uaebc\ud480", "\ube14\ub7ec\uc154", "\ub208\uc379", "\ubdf0\ud2f0\ud4e8\uc5b4", "\ub2e8\ubc1c\uba38\ub9ac", "\ud53c\ubd80", "\uc624\ub80c\uc9c0", "\uba54\uc774\ud06c\uc5c5", "\ud06c\ub85c\uc170", "\ud0c8\uc0c9", "\ube0c\ub77c\uc6b4", "\uc544\uc774\uc720", "\ucd94\uc704", "\uceec\ub7ec", "\ud5e4\uc5b4", "\ud53c\uce58", "\uc544\uc774\uc100\ub3c4\uc6b0", "\ubdf0\ud2f0", "\ubaa8\ubc1c", "\uc2a4\ud0a8", "\ub808\ub4dc", "\uc2a4\ud0a8\ucf00\uc5b4", "\uace8\ud504", "\ubbf8\uc6a9\uc2e4", "\ube14\ub8e8", "\uc2dc\uc220", "\uc5bc\uad74", "\uc0c9\uc870", "\ud32c\ud1a4", "\ud551\ud06c", "\uc2a4\ud0c0\uc77c", "\ud32c\uce20", "\ud30c\uc2a4\ud154", "\uc131\ubd84", "\ubd84\uc704\uae30", "\uc548\uacbd", "\uc0c9\uac10", "\ub9e4\ub825", "\uc790\uc5f0", "\ud328\uc158", "\uc644\uc131", "\uc778\uae30", "\ud37c\uc988", "\uc778\ud14c\ub9ac\uc5b4", "\ud2b8\ub80c\ub4dc", "\ub3c5\ud2b9", "\ub514\uc790\uc778", "\ub2e4\uc59 ...

# %% [markdown]
# ## 문서 별 Topic 분포

# %%
for i, topic_list in enumerate(ldamodel[corpus]):
    print(f'{i}번째 문서의 topic 비중: {topic_list}')
    if i==5:
        break
# Out:
# 0번째 문서의 topic 비중: [(2, 0.99386334)]
# 1번째 문서의 topic 비중: [(2, 0.9933778)]
# 2번째 문서의 topic 비중: [(2, 0.99072015)]
# 3번째 문서의 topic 비중: [(2, 0.9950052)]
# 4번째 문서의 topic 비중: [(2, 0.9956223)]
# 5번째 문서의 topic 비중: [(2, 0.9938269)]

# %% [markdown]
# ### 각 문서에 대해서 Topic의 비중을 나타내는 함수 작성

# %%
## 교수님 코드 

def get_topic_ratio_for_each_document(ldamodel, corpus):
    results = []
    for i, topic_list in enumerate(ldamodel[corpus]):
        sorted_topic_list = sorted(topic_list, key = lambda x: x[1], reverse=True)
        most_important_topic, most_important_ratio = sorted_topic_list[0]
        doc_result = [i, most_important_topic, most_important_ratio, sorted_topic_list]
        results.append(doc_result)
        
    results = pd.DataFrame(results, columns = ['문서 번호', '가장 비중이 높은 토픽', '가장 높은 토픽의 비중', '각 토픽의 비중'])
    return results

# %%
df_results = get_topic_ratio_for_each_document(ldamodel, corpus)

df_results
# Out:
#       문서 번호  가장 비중이 높은 토픽  가장 높은 토픽의 비중                             각 토픽의 비중
# 0         0             2      0.993864                    [(2, 0.99386376)]
# 1         1             2      0.993377                    [(2, 0.99337673)]
# 2         2             2      0.990721                     [(2, 0.9907209)]
# 3         3             2      0.995007                    [(2, 0.99500686)]
# 4         4             2      0.995622                    [(2, 0.99562156)]
# ...     ...           ...           ...                                  ...
# 2923   2923             0      0.995627                     [(0, 0.9956271)]
# 2924   2924             1      0.997923                    [(1, 0.99792254)]
# 2925   2925             2      0.753575    [(2, 0.7535754), (0, 0.24343684)]
# 2926   2926             1      0.970164  [(1, 0.97016394), (0, 0.026052335)]
# 2927   2927             1      0.526178    [(1, 0.52617764), (2, 0.4659631)]
#
# [2928 rows x 4 columns]

# %%
## 참고 사이트: https://wikidocs.net/30708

def make_topictable_per_doc(ldamodel, corpus):
    # 데이터를 저장할 빈 리스트 초기화
    topic_data = []

    # 몇 번째 문서인지를 의미하는 문서 번호와 해당 문서의 토픽 비중을 한 줄씩 꺼내온다.
    for i, topic_list in enumerate(ldamodel[corpus]):
        doc = topic_list[0] if ldamodel.per_word_topics else topic_list            
        doc = sorted(doc, key=lambda x: (x[1]), reverse=True)
        # 각 문서에 대해서 비중이 높은 토픽순으로 토픽을 정렬한다.
        # EX) 정렬 전 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (10번 토픽, 5%), (12번 토픽, 21.5%), 
        # Ex) 정렬 후 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (12번 토픽, 21.5%), (10번 토픽, 5%)
        # 48 > 25 > 21 > 5 순으로 정렬이 된 것.

        # 모든 문서에 대해서 각각 아래를 수행
        for j, (topic_num, prop_topic) in enumerate(doc): #  몇 번 토픽인지와 비중을 나눠서 저장한다.
            if j == 0:  # 정렬을 한 상태이므로 가장 앞에 있는 것이 가장 비중이 높은 토픽
                topic_data.append([i, int(topic_num), round(prop_topic, 4), topic_list])
                # 가장 비중이 높은 토픽과, 가장 비중이 높은 토픽의 비중과, 전체 토픽의 비중을 저장한다.
            else:
                break
            
    # 리스트를 데이터프레임으로 변환
    topic_table = pd.DataFrame(topic_data, columns=['문서 번호', '가장 비중이 높은 토픽', '가장 높은 토픽의 비중', '각 토픽의 비중'])

    return(topic_table)

# %%
topictable = make_topictable_per_doc(ldamodel, corpus)
topictable = topictable.reset_index() # 문서 번호을 의미하는 열(column)로 사용하기 위해서 인덱스 열을 하나 더 만든다.
topictable[:10]
# Out:
#    index  문서 번호  가장 비중이 높은 토픽  가장 높은 토픽의 비중  \
# 0      0      0             2        0.9939
# 1      1      1             2        0.9934
# 2      2      2             2        0.9907
# 3      3      3             2        0.9950
# 4      4      4             2        0.9956
# 5      5      5             2        0.9938
# 6      6      6             0        0.3333
# 7      7      7             0        0.3333
# 8      8      8             0        0.3333
# 9      9      9             0        0.3333
#
#                                             각 토픽의 비중
# 0                                  [(2, 0.99386454)]
# 1                                  [(2, 0.99337584)]
# 2                                   [(2, 0.9907219)]
# 3                                   [(2, 0.9950048)]
# 4                                   [(2, 0.9956221)]
# 5                                    [(2, 0.993825)]
# 6  [(0, 0.33333334), (1, 0.33333334), (2, 0.33333...
# 7  [(0, 0.33333334), (1, 0.33333334), (2, 0.33333...
# 8  [(0, 0.33333334), (1, 0.33333334), (2, 0.33333...
# 9  [(0, 0.33333334), (1, 0.33333334), (2, 0.33333...

# %%
## 교수님 코드 + 각 토픽 별 키워드를 볼 수 있는 함수 (GPT의 도움을 조금 받음!)


def get_topic_keywords(ldamodel, num_keywords=5):
    topic_keywords = {}
    for topic_id in range(ldamodel.num_topics):
        keywords = [word for word, _ in ldamodel.show_topic(topic_id, topn=num_keywords)]
        topic_keywords[topic_id] = keywords
    return topic_keywords

def get_topic_ratio_for_each_document(ldamodel, corpus):
    topic_keywords = get_topic_keywords(ldamodel)
    results = []
    for i, topic_list in enumerate(ldamodel[corpus]):
        sorted_topic_list = sorted(topic_list, key = lambda x: x[1], reverse=True)
        most_important_topic, most_important_ratio = sorted_topic_list[0]
        second_most_important_topic, second_most_important_ratio = sorted_topic_list[1] if len(sorted_topic_list) > 1 else (None, 0)

        keywords_1 = ", ".join(topic_keywords[most_important_topic])
        keywords_2 = ", ".join(topic_keywords[second_most_important_topic]) if second_most_important_topic is not None else ''
        doc_result = [i, most_important_topic, most_important_ratio, sorted_topic_list, keywords_1, keywords_2]
        results.append(doc_result)
        
    results = pd.DataFrame(results, columns=['문서 번호', '가장 비중이 높은 토픽', '가장 높은 토픽의 비중', '각 토픽의 비중', 'Top1_Topic_keyword', 'Top2_Topic_keyword'])
    return results

# %%
df_results = get_topic_ratio_for_each_document(ldamodel, corpus)

df_results
# Out:
#       문서 번호  가장 비중이 높은 토픽  가장 높은 토픽의 비중                             각 토픽의 비중  \
# 0         0             2      0.993865                     [(2, 0.9938654)]
# 1         1             2      0.993374                     [(2, 0.9933737)]
# 2         2             2      0.990724                      [(2, 0.990724)]
# 3         3             2      0.995007                     [(2, 0.9950068)]
# 4         4             2      0.995621                     [(2, 0.9956207)]
# ...     ...           ...           ...                                  ...
# 2923   2923             0      0.995626                    [(0, 0.99562556)]
# 2924   2924             1      0.997922                    [(1, 0.99792224)]
# 2925   2925             2      0.753633    [(2, 0.7536332), (0, 0.24337898)]
# 2926   2926             1      0.972639  [(1, 0.97263896), (0, 0.023576641)]
# 2927   2927             1      0.526291     [(1, 0.526291), (2, 0.46584973)]
#
#          Top1_Topic_keyword     Top2_Topic_keyword
# 0      컬러, 트렌드, 스타일, 패션, 피부
# 1      컬러, 트렌드, 스타일, 패션, 피부
# 2      컬러, 트렌드, 스타일, 패션, 피부
# 3      컬러, 트렌드, 스타일, 패션, 피부
# 4      컬러, 트렌드, 스타일, 패션, 피부
# ...                     ...                    ...
# 2923  트렌드, 디자인, 시장, 패션, 스타일
# 2924    트렌드, 대하, 활용, 환경, 다양
# 2925   컬러, 트렌드, 스타일, 패션, 피부  트렌드, 디자인, 시장, 패션, 스타일
# 2926    트렌드, 대하, 활용, 환경, 다양  트렌드, 디자인, 시장, 패션, 스타일
# 2927    트렌드, 대하, 활용, 환경, 다양   컬러, 트렌드, 스타일, 패션, 피부
#
# [2928 rows x 6 columns]
